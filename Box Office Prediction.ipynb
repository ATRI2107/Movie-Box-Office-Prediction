# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies=pd.read_csv('tmdb_5000_movies.csv',index_col=3)
credits=pd.read_csv('tmdb_5000_credits.csv',index_col=0)

# %%
movies.head(2)
# Out:
#           budget                                             genres  \
# id
# 19995  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                            homepage  \
# id
# 19995                   http://www.avatarmovie.com/
# 285    http://disney.go.com/disneypictures/pirates/
#
#                                                 keywords original_language  \
# id
# 19995  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285    [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                                  original_title  \
# id
# 19995                                    Avatar
# 285    Pirates of the Caribbean: At World's End
#
#                                                 overview  popularity  \
# id
# 19995  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
movies['profit']=movies.revenue-movies.budget
movies.head(2)
# Out:
#           budget                                             genres  \
# id
# 19995  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                            homepage  \
# id
# 19995                   http://www.avatarmovie.com/
# 285    http://disney.go.com/disneypictures/pirates/
#
#                                                 keywords original_language  \
# id
# 19995  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285    [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                                  original_title  \
# id
# 19995                                    Avatar
# 285    Pirates of the Caribbean: At World's End
#
#                                                 overview  popularity  \
# id
# 19995  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
credits.head(2)
# Out:
#                                              title  \
# movie_id
# 19995                                       Avatar
# 285       Pirates of the Caribbean: At World's End
#
#                                                        cast  \
# movie_id
# 19995     [{"cast_id": 242, "character": "Jake Sully", "...
# 285       [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                        crew
# movie_id
# 19995     [{"credit_id": "52fe48009251416c750aca23", "de...
# 285       [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %% [markdown]
# <h1>2. Data Cleaning </h1>

# %%
credits.drop(['title'],axis=1,inplace=True)

# %%
credits.head(2)
# Out:
#                                                        cast  \
# movie_id
# 19995     [{"cast_id": 242, "character": "Jake Sully", "...
# 285       [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                        crew
# movie_id
# 19995     [{"credit_id": "52fe48009251416c750aca23", "de...
# 285       [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
df=movies.join(credits)
df.head(2)
# Out:
#           budget                                             genres  \
# id
# 19995  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285    300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                            homepage  \
# id
# 19995                   http://www.avatarmovie.com/
# 285    http://disney.go.com/disneypictures/pirates/
#
#                                                 keywords original_language  \
# id
# 19995  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285    [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                                  original_title  \
# id
# 19995                                    Avatar
# 285    Pirates of the Caribbean: At World's End
#
#                                                 overview  popularity  \
# id
# 19995  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 19995 to 25975
# Data columns (total 22 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# vote_average            4803 non-null float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df['label_encoded']=labelencoder.fit_transform(df['original_language'])

# %%
df=df[df['budget']>0]

# %%
df.dropna(inplace=True)
df.head()
# Out:
#            budget                                             genres  \
# id
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  \
# id
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
# 49026             http://www.thedarkknightrises.com/
# 49529           http://movies.disney.com/john-carter
#
#                                                  keywords original_language  \
# id
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# ...

# %%
from pandas.io.json import json_normalize
import json
def json_decode(data,key):
    result=[]
    data=json.loads(data)
    for item in data:
        result.append(item[key])
    return result

# %%
df.genres=df.genres.apply(json_decode,key='name')
df.keywords=df.keywords.apply(json_decode,key='name')
df.production_companies=df.production_companies.apply(json_decode,key='name')
df.production_countries=df.production_countries.apply(json_decode,key='name')
df.cast=df.cast.apply(json_decode,key='name')
df.crew=df.crew.apply(json_decode,key='name')
df.spoken_languages=df.spoken_languages.apply(json_decode,key='name')

# %%
df.head(2)
# Out:
#           budget                                         genres  \
# id
# 19995  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 285    300000000                   [Adventure, Fantasy, Action]
#
#                                            homepage  \
# id
# 19995                   http://www.avatarmovie.com/
# 285    http://disney.go.com/disneypictures/pirates/
#
#                                                 keywords original_language  \
# id
# 19995  [culture clash, future, space war, space colon...                en
# 285    [ocean, drug abuse, exotic island, east india ...                en
#
#                                  original_title  \
# id
# 19995                                    Avatar
# 285    Pirates of the Caribbean: At World's End
#
#                                                 overview  popularity  \
# id
# 19995  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %% [markdown]
# <h1>3. Data Visualization </h1>

# %% [markdown]
# <h3>3.1 Word Cloud</h3>

# %%
from wordcloud import WordCloud
genres={}
for i in df['genres']:
    for j in i:
        if j not in genres:
            genres[j]=1
        else:
            genres[j]+=1
plt.figure(figsize=(12,8))
wordcloud=WordCloud(background_color="white",width=1000,height=1000,max_words=10,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(genres)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(15,11))
g1=sns.boxenplot(x='original_language',y='revenue',data=df[(df['original_language'].isin((df['original_language'].sort_values().value_counts()[:10].index.values)))])
g1.set_title("Revenue by Language",fontsize=20)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_xlabel("Language",fontsize=18)
g1.set_ylabel("Revenue",fontsize=18)
plt.show()
